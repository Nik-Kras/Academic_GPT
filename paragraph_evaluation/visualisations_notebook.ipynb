# %%
import pandas as pd
from visualisations import visualise_all_models_distributions 


dataset = pd.read_csv("data/DatasetAllPrompts_multiindex.csv", header=[0, 1], index_col=0)
visualise_all_models_distributions(dataset)

# %%
from visualisations import compare_all_features_to_all_models

compare_all_features_to_all_models(dataset)

# %%
from visualisations import visualise_all_kde

best_fit = pd.read_csv("data/FeatureModelBestFit.csv", index_col=0, header=None).squeeze("columns")
visualise_all_kde(dataset, best_fit)
